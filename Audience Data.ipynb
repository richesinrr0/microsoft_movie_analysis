# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/zippedData/rotten_tomatoes_movies.csv.gz')
df
# Out:
#                         rotten_tomatoes_link  \
# 0                                  m/0814255
# 1                                  m/0878835
# 2                                       m/10
# 3                     m/1000013-12_angry_men
# 4      m/1000079-20000_leagues_under_the_sea
# ...                                      ...
# 17707                            m/zoot_suit
# 17708                             m/zootopia
# 17709                      m/zorba_the_greek
# 17710                                 m/zulu
# 17711                            m/zulu_dawn
#
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# ...

# %%
df = df[['movie_title', 'content_rating', 'audience_count']]
df
# Out:
#                                          movie_title content_rating  \
# 16297                                        Titanic          PG-13
# 15410  The Lord of the Rings: The Return of the King          PG-13
# 13694                                     Spider-Man          PG-13
# 13276                                        Shrek 2             PG
# 7526             Harry Potter and the Goblet of Fire          PG-13
# ...                                              ...            ...
# 16731                                          Union             NR
# 15876                                  The Surrogate             NR
# 11498      Out Stealing Horses (Ut og Stjæle Hester)             NR
# 7354                                    Guest Artist             NR
# 17119                   The Wedding Banquet (Xi yan)              R
#
#        audience_count
# 16297      35797635.0
# 15410      34679773.0
# 13694      34297354.0
# 13276      34232524.0
# 7526       34153607.0
# ...

# %%
df = df.sort_values('audience_count', ascending=False)
df
# Out:
#                                          movie_title content_rating  \
# 16297                                        Titanic          PG-13
# 15410  The Lord of the Rings: The Return of the King          PG-13
# 13694                                     Spider-Man          PG-13
# 13276                                        Shrek 2             PG
# 7526             Harry Potter and the Goblet of Fire          PG-13
# ...                                              ...            ...
# 16731                                          Union             NR
# 15876                                  The Surrogate             NR
# 11498      Out Stealing Horses (Ut og Stjæle Hester)             NR
# 7354                                    Guest Artist             NR
# 17119                   The Wedding Banquet (Xi yan)              R
#
#        audience_count
# 16297      35797635.0
# 15410      34679773.0
# 13694      34297354.0
# 13276      34232524.0
# 7526       34153607.0
# ...

# %%
df = df[df['audience_count'].notna()]
df
#audience_count column ordered from greatest to least, and NaN values dropped
# Out:
#                                          movie_title content_rating  \
# 16297                                        Titanic          PG-13
# 15410  The Lord of the Rings: The Return of the King          PG-13
# 13694                                     Spider-Man          PG-13
# 13276                                        Shrek 2             PG
# 7526             Harry Potter and the Goblet of Fire          PG-13
# ...                                              ...            ...
# 16731                                          Union             NR
# 15876                                  The Surrogate             NR
# 11498      Out Stealing Horses (Ut og Stjæle Hester)             NR
# 7354                                    Guest Artist             NR
# 17119                   The Wedding Banquet (Xi yan)              R
#
#        audience_count
# 16297      35797635.0
# 15410      34679773.0
# 13694      34297354.0
# 13276      34232524.0
# 7526       34153607.0
# ...

# %%
df = df[df['audience_status'].notna()]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'audience_status'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-7c5d9f4eba0f> in <module>
# ...

# %%
df['audience_count'].mean()
# Out:
# 154127.37154125838

# %%
df = df.dropna()
df
# Out:
#                                          movie_title content_rating  \
# 16297                                        Titanic          PG-13
# 15410  The Lord of the Rings: The Return of the King          PG-13
# 13694                                     Spider-Man          PG-13
# 13276                                        Shrek 2             PG
# 7526             Harry Potter and the Goblet of Fire          PG-13
# ...                                              ...            ...
# 16731                                          Union             NR
# 15876                                  The Surrogate             NR
# 11498      Out Stealing Horses (Ut og Stjæle Hester)             NR
# 7354                                    Guest Artist             NR
# 17119                   The Wedding Banquet (Xi yan)              R
#
#        audience_count
# 16297      35797635.0
# 15410      34679773.0
# 13694      34297354.0
# 13276      34232524.0
# 7526       34153607.0
# ...

# %%
df.content_rating.value_counts()
# Out:
# R        6089
# NR       4521
# PG-13    2861
# PG       2067
# G         653
# NC17       36
# Name: content_rating, dtype: int64

# %%
df_R = df.loc[df['content_rating'] == 'R']
df_R
# Out:
#                         movie_title content_rating  audience_count
# 7052                      Gladiator              R      34128168.0
# 2662                   American Pie              R      33781574.0
# 10183                    The Matrix              R      33324202.0
# 16106  There's Something About Mary              R      33121539.0
# 17120              Wedding Crashers              R      32961772.0
# ...                             ...            ...             ...
# 13019                  See You Soon              R            16.0
# 8437    Intrigo: Death of an Author              R            16.0
# 11508                       Outlaws              R            13.0
# 14102                    Supervized              R            12.0
# 17119  The Wedding Banquet (Xi yan)              R             5.0
#
# [6089 rows x 3 columns]

# %%
df_R.mean()
# Out:
# audience_count    122256.526195
# dtype: float64

# %%
df_PG13 = df.loc[df['content_rating'] == 'PG-13']
df_PG13
# Out:
#                                          movie_title content_rating  \
# 16297                                        Titanic          PG-13
# 15410  The Lord of the Rings: The Return of the King          PG-13
# 13694                                     Spider-Man          PG-13
# 7526             Harry Potter and the Goblet of Fire          PG-13
# 9014                                       King Kong          PG-13
# ...                                              ...            ...
# 13408                                Slay the Dragon          PG-13
# 12030                                           Prey          PG-13
# 11308                                 Olympic Dreams          PG-13
# 5986                                         Emperor          PG-13
# 14937                                      The Fight          PG-13
#
#        audience_count
# 16297      35797635.0
# 15410      34679773.0
# 13694      34297354.0
# 7526       34153607.0
# 9014       33766734.0
# ...

# %%
df_PG13.mean()
# Out:
# audience_count    431097.879762
# dtype: float64

# %%
plot_fig, plot_ax = plt.subplots(figsize=(15, 12))

sns.barplot(x="content_rating", y="audience_count", data=df)
plot_ax.set_xlabel('Content Rating', fontsize=15)
plot_ax.set_ylabel('Mean Audience Count', fontsize=15);
plot_ax.set_title('Mean Audience per Movie by Content Rating', fontsize=23);
