# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('data/zippedData/rotten_tomatoes_movies.csv.gz')
df
# Out:
#                         rotten_tomatoes_link  \
# 0                                  m/0814255
# 1                                  m/0878835
# 2                                       m/10
# 3                     m/1000013-12_angry_men
# 4      m/1000079-20000_leagues_under_the_sea
# ...                                      ...
# 17707                            m/zoot_suit
# 17708                             m/zootopia
# 17709                      m/zorba_the_greek
# 17710                                 m/zulu
# 17711                            m/zulu_dawn
#
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# ...

# %%
df = df[['movie_title', 'content_rating', 'original_release_date', 'audience_status', 'audience_count']]
df
# Out:
#                                              movie_title content_rating  \
# 0      Percy Jackson & the Olympians: The Lightning T...             PG
# 1                                            Please Give              R
# 2                                                     10              R
# 3                        12 Angry Men (Twelve Angry Men)             NR
# 4                           20,000 Leagues Under The Sea              G
# ...                                                  ...            ...
# 17707                                          Zoot Suit              R
# 17708                                           Zootopia             PG
# 17709                                    Zorba the Greek             NR
# 17710                                               Zulu             PG
# 17711                                          Zulu Dawn             PG
#
#       original_release_date audience_status  audience_count
# ...

# %%
df = df.sort_values('audience_count', ascending=False)
df
# Out:
#                                          movie_title content_rating  \
# 16297                                        Titanic          PG-13
# 15410  The Lord of the Rings: The Return of the King          PG-13
# 13694                                     Spider-Man          PG-13
# 13276                                        Shrek 2             PG
# 7526             Harry Potter and the Goblet of Fire          PG-13
# ...                                              ...            ...
# 17522                                  Working Girls             NR
# 17607                                        Yom Yom             NR
# 17609                                       Yosemite              R
# 17618                   You Don't Need Feet to Dance             NR
# 17671                                              Z             NR
#
#       original_release_date audience_status  audience_count
# 16297            1997-12-19         Upright      35797635.0
# ...

# %%
df = df[df['audience_count'].notna()]
df
#audience_count column ordered from greatest to least, and NaN values dropped
# Out:
#                                          movie_title content_rating  \
# 16297                                        Titanic          PG-13
# 15410  The Lord of the Rings: The Return of the King          PG-13
# 13694                                     Spider-Man          PG-13
# 13276                                        Shrek 2             PG
# 7526             Harry Potter and the Goblet of Fire          PG-13
# ...                                              ...            ...
# 6157                              Evil Little Things             NR
# 1951                     2 in the Bush: A Love Story             NR
# 10243                            Measure for Measure             NR
# 7354                                    Guest Artist             NR
# 17119                   The Wedding Banquet (Xi yan)              R
#
#       original_release_date audience_status  audience_count
# 16297            1997-12-19         Upright      35797635.0
# ...

# %%
df = df[df['audience_status'].notna()]
df
# Out:
#                                          movie_title content_rating  \
# 16297                                        Titanic          PG-13
# 15410  The Lord of the Rings: The Return of the King          PG-13
# 13694                                     Spider-Man          PG-13
# 13276                                        Shrek 2             PG
# 7526             Harry Potter and the Goblet of Fire          PG-13
# ...                                              ...            ...
# 6157                              Evil Little Things             NR
# 1951                     2 in the Bush: A Love Story             NR
# 10243                            Measure for Measure             NR
# 7354                                    Guest Artist             NR
# 17119                   The Wedding Banquet (Xi yan)              R
#
#       original_release_date audience_status  audience_count
# 16297            1997-12-19         Upright      35797635.0
# ...

# %%
df['audience_status'].value_counts()
# Out:
# Upright    9389
# Spilled    7874
# Name: audience_status, dtype: int64

# %%
df['audience_count'].mean()
# Out:
# 145132.55274286045

# %%
df['audience_status'].value_counts()
# Out:
# Upright    9389
# Spilled    7874
# Name: audience_status, dtype: int64

# %%
df = df[df.audience_status !='Spilled']
df
# Out:
#                                          movie_title content_rating  \
# 16297                                        Titanic          PG-13
# 15410  The Lord of the Rings: The Return of the King          PG-13
# 13694                                     Spider-Man          PG-13
# 13276                                        Shrek 2             PG
# 7526             Harry Potter and the Goblet of Fire          PG-13
# ...                                              ...            ...
# 15876                                  The Surrogate             NR
# 11498      Out Stealing Horses (Ut og Stjæle Hester)             NR
# 1951                     2 in the Bush: A Love Story             NR
# 10243                            Measure for Measure             NR
# 17119                   The Wedding Banquet (Xi yan)              R
#
#       original_release_date audience_status  audience_count
# 16297            1997-12-19         Upright      35797635.0
# ...

# %%
df = df[df.audience_count>=11000]
df
#df filtered by audience_count from greatest to least, and only audience_status is upright
# Out:
#                                          movie_title content_rating  \
# 16297                                        Titanic          PG-13
# 15410  The Lord of the Rings: The Return of the King          PG-13
# 13694                                     Spider-Man          PG-13
# 13276                                        Shrek 2             PG
# 7526             Harry Potter and the Goblet of Fire          PG-13
# ...                                              ...            ...
# 14962                               The Fluffy Movie          PG-13
# 7829                  A Home at the End of the World              R
# 1250                                An Ideal Husband          PG-13
# 7323                                    The Grifters              R
# 4055                                  Broadcast News              R
#
#       original_release_date audience_status  audience_count
# 16297            1997-12-19         Upright      35797635.0
# ...

# %%
df.content_rating.value_counts()
# Out:
# R        1482
# PG-13     942
# PG        577
# G         226
# NR        172
# NC17       11
# Name: content_rating, dtype: int64
